# %% [markdown]
# # Top
#
# A notebook for practicing and re-learning basic Python for data science.

# %% [markdown]
# ## Set up and Data

# %%
# Loading the package
import pandas as pd

# %% [markdown]
# Now, let's load the rental listing sample data set.

# %%
# Load the CSV
df = pd.read_csv("data/rental_sample_23ward_center.csv")

# %% [markdown]
# ## Through the ringer
# Let's take a peek at the data.

# %%
df.head()
# Out:
#         region_en    name_en                  building_name rent_type  \
# 0  23 Ward Center  Bunkyo-ku             ＪＲ山手線 田端駅 15階建 築3年   賃貸マンション
# 1  23 Ward Center  Bunkyo-ku  東京メトロ丸ノ内線 御茶ノ水駅 地下2地上11階建 築8年   賃貸マンション
# 2  23 Ward Center  Bunkyo-ku                      フェニックス飯田橋   賃貸マンション
# 3  23 Ward Center  Bunkyo-ku                   スカイコート東大前壱番館   賃貸マンション
# 4  23 Ward Center  Bunkyo-ku         東京メトロ有楽町線 江戸川橋駅 8階建 新築   賃貸マンション
#
#       address address_cho  building_age  floors_total  floor  rent  ...  \
# 0  東京都文京区千駄木４   東京都文京区千駄木             3            15      3  13.0  ...
# 1   東京都文京区湯島２    東京都文京区湯島             8             2      4  11.8  ...
# 2   東京都文京区水道１    東京都文京区水道            12             6      5  12.0  ...
# 3   東京都文京区西片２    東京都文京区西片            21             9      3  11.0  ...
# 4   東京都文京区水道１    東京都文京区水道             0             8      4  16.1  ...
#
#    train_line_2  train_station_2  walk_time_2 train_line_3  train_station_3  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2509 entries, 0 to 2508
# Data columns (total 38 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   region_en            2509 non-null   object
#  1   name_en              2509 non-null   object
#  2   building_name        2509 non-null   object
#  3   rent_type            2509 non-null   object
#  4   address              2509 non-null   object
#  5   address_cho          2509 non-null   object
#  6   building_age         2509 non-null   int64
#  7   floors_total         2509 non-null   int64
#  8   floor                2509 non-null   int64
#  9   rent                 2509 non-null   float64
#  10  condo_fee            2509 non-null   int64
#  11  deposit              2509 non-null   float64
#  12  reikin               2509 non-null   float64
#  13  layout               2509 non-null   object
#  14  room_count           2509 non-null   int64
# ...

# %%
df.describe()
# Out:
#        building_age  floors_total        floor         rent     condo_fee  \
# count   2509.000000   2509.000000  2509.000000  2509.000000   2509.000000
# mean      18.557593      7.339578     5.536070    17.683284   9446.480670
# std       14.642346      5.912597     5.069847    10.505799   6219.574473
# min        0.000000      1.000000     1.000000     2.500000      0.000000
# 25%        6.000000      3.000000     2.000000    10.700000   5000.000000
# 50%       18.000000      6.000000     4.000000    14.900000  10000.000000
# 75%       25.000000     11.000000     7.000000    22.000000  12000.000000
# max       65.000000     58.000000    52.000000   130.000000  55000.000000
#
#             deposit        reikin   room_count  total_partitions  \
# count  2.509000e+03  2.509000e+03  2509.000000       2509.000000
# mean   1.644272e+05  1.300216e+05     1.229574          2.990434
# std    2.100410e+05  1.425061e+05     0.548219          1.484606
# ...

# %%
df.describe(include = 'object')
# Out:
#              region_en      name_en                building_name rent_type  \
# count             2509         2509                         2509      2509
# unique               1            6                         2228         4
# top     23 Ward Center  Shinjuku-ku  HARUMI FLAG PORT VILLAGE A棟   賃貸マンション
# freq              2509          715                            6      2351
#
#            address address_cho layout  \
# count         2509        2509   2509
# unique         472         219     24
# top     東京都新宿区北新宿１   東京都渋谷区代々木     1K
# freq            25          68    807
#
#                                                detail_url train_line_1  \
# count                                                2509         2509
# unique                                               2509           33
# top     https://suumo.jp/chintai/jnc_000098443370/?bc=...       都営大江戸線
# freq                                                    1          338
#
# ...

# %% [markdown]
# ## Basic Data Transformation
#
# Let's try to:
#
# 1. Filter for observations in Shinjuku-ku
# 2. Filter for アパート in Bunkyo-ku
